# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('8b380cae-f944-42bc-8d44-d0b791b997b8.xlsx'  )

# %%
df.head()
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# ...

# %%
df.tail()
# Out:
#         id  age  education sex is_smoking  cigsPerDay  BPMeds  \
# 3385  3385   60        1.0   F         NO         0.0     0.0
# 3386  3386   46        1.0   F         NO         0.0     0.0
# 3387  3387   44        3.0   M        YES         3.0     0.0
# 3388  3388   60        1.0   M         NO         0.0     NaN
# 3389  3389   54        3.0   F         NO         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3385                0             0         0    261.0  123.5   79.0  29.28
# 3386                0             0         0    199.0  102.0   56.0  21.96
# 3387                0             1         0    352.0  164.0  119.0  28.92
# 3388                0             1         0    191.0  167.0  105.0  23.01
# 3389                0             0         0    288.0  124.0   77.0  29.88
#
#       heartRate  glucose  TenYearCHD
# 3385       70.0    103.0           0
# 3386       80.0     84.0           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   education        3303 non-null   float64
#  3   sex              3390 non-null   object
#  4   is_smoking       3390 non-null   object
#  5   cigsPerDay       3368 non-null   float64
#  6   BPMeds           3346 non-null   float64
#  7   prevalentStroke  3390 non-null   int64
#  8   prevalentHyp     3390 non-null   int64
#  9   diabetes         3390 non-null   int64
#  10  totChol          3352 non-null   float64
#  11  sysBP            3390 non-null   float64
#  12  diaBP            3390 non-null   float64
#  13  BMI              3376 non-null   float64
#  14  heartRate        3389 non-null   float64
#  15  glucose          3086 non-null   float64
# ...

# %%
df.describe()
# Out:
#                 id          age    education   cigsPerDay       BPMeds  \
# count  3390.000000  3390.000000  3303.000000  3368.000000  3346.000000
# mean   1694.500000    49.542183     1.970936     9.069477     0.029886
# std     978.753033     8.592878     1.019081    11.879078     0.170299
# min       0.000000    32.000000     1.000000     0.000000     0.000000
# 25%     847.250000    42.000000     1.000000     0.000000     0.000000
# 50%    1694.500000    49.000000     2.000000     0.000000     0.000000
# 75%    2541.750000    56.000000     3.000000    20.000000     0.000000
# max    3389.000000    70.000000     4.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol       sysBP  \
# count      3390.000000   3390.000000  3390.000000  3352.000000  3390.00000
# mean          0.006490      0.315339     0.025664   237.074284   132.60118
# std           0.080309      0.464719     0.158153    45.247430    22.29203
# ...

# %%
df.shape
# Out:
# (3390, 17)

# %%
df.columns
# Out:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %% [markdown]
# # 1) dropping duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#no duplicates

# %%
# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\Hasan Shaik\AppData\Local\Temp\ipykernel_22172\915092904.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
#dropping useless columns by domain knowledge
df.drop(['id' ,'education','is_smoking','diaBP', 'glucose'] , axis=1 , inplace=True)

# %%
df.pop('sex')
# Out:
# 0       F
# 1       M
# 2       F
# 3       M
# 4       F
#        ..
# 3385    F
# 3386    F
# 3387    M
# 3388    M
# 3389    F
# Name: sex, Length: 3390, dtype: object

# %%
df.shape
# Out:
# (3390, 11)

# %% [markdown]
# # 2)missing value treatment

# %%
df.isnull().sum()
# Out:
# age                 0
# cigsPerDay         22
# BPMeds             44
# prevalentStroke     0
# prevalentHyp        0
# diabetes            0
# totChol            38
# sysBP               0
# BMI                14
# heartRate           1
# TenYearCHD          0
# dtype: int64

# %%
# Calculate the median of the 'cigsPerDay' column
cigsPerDay_median = df['cigsPerDay'].median()

# Fill null values in the 'cigsPerDay' column with the median value
df['cigsPerDay'] = df['cigsPerDay'].fillna(cigsPerDay_median)

# %%
# Assuming 'df' is your DataFrame
mode_bpmeds = df['BPMeds'].mode().iloc[0]  # Calculate the mode of the 'BPMeds' column

# Fill null values with the mode
df['BPMeds'] = df['BPMeds'].fillna(mode_bpmeds)

# %%
# Assuming 'df' is your DataFrame
# Calculate the median of the 'cigsPerDay' column
cigsPerDay_median = df['totChol'].median()

# Fill null values in the 'cigsPerDay' column with the median value
df['totChol'] = df['totChol'].fillna(cigsPerDay_median)

# %%
# Assuming 'df' is your DataFrame
# Calculate the median of the 'cigsPerDay' column
cigsPerDay_median = df['BMI'].median()

# Fill null values in the 'cigsPerDay' column with the median value
df['BMI'] = df['BMI'].fillna(cigsPerDay_median)

# %%
heart_median = df['heartRate'].median()

# Fill null values in the 'cigsPerDay' column with the median value
df['heartRate'] = df['heartRate'].fillna(heart_median)

# %%
df.isnull().sum()
# Out:
# age                0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# BMI                0
# heartRate          0
# TenYearCHD         0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    age  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  diabetes  totChol  \
# 0   64         3.0     0.0                0             0         0    221.0
# 1   36         0.0     0.0                0             1         0    212.0
# 2   46        10.0     0.0                0             0         0    250.0
# 3   50        20.0     0.0                0             1         0    233.0
# 4   64        30.0     0.0                0             0         0    241.0
#
#    sysBP    BMI  heartRate  TenYearCHD
# 0  148.0  25.38       90.0           1
# 1  168.0  29.77       72.0           0
# 2  116.0  20.35       88.0           0
# 3  158.0  28.26       68.0           1
# 4  136.5  26.42       70.0           0

# %%
df.shape
# Out:
# (3390, 11)

# %% [markdown]
# # 3) converting datatype of specified columns to int

# %%
columns_to_convert = ['cigsPerDay', 'BPMeds', 'totChol', 'sysBP', 'heartRate']
df[columns_to_convert] = df[columns_to_convert].astype(int)

print(df)
# Out:
#       age  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  diabetes  \
# 0      64           3       0                0             0         0
# 1      36           0       0                0             1         0
# 2      46          10       0                0             0         0
# 3      50          20       0                0             1         0
# 4      64          30       0                0             0         0
# ...   ...         ...     ...              ...           ...       ...
# 3385   60           0       0                0             0         0
# 3386   46           0       0                0             0         0
# 3387   44           3       0                0             1         0
# 3388   60           0       0                0             1         0
# 3389   54           0       0                0             0         0
#
#       totChol  sysBP    BMI  heartRate  TenYearCHD
# 0         221    148  25.38         90           1
# ...

# %%
df.dtypes
# Out:
# age                  int64
# cigsPerDay           int32
# BPMeds               int32
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol              int32
# sysBP                int32
# BMI                float64
# heartRate            int32
# TenYearCHD           int64
# dtype: object

# %% [markdown]
# # 4) Dealing with outliers and capping

# %%
columns_to_visualize = ['age', 'cigsPerDay', 'totChol', 'sysBP', 'BMI', 'heartRate']

# Create box plots for each column
plt.figure(figsize=(12, 8))
for column in columns_to_visualize:
    sns.boxplot(x=column, data=df)
    plt.title(f"Box Plot of {column}")
    plt.show()

# %%
# Create box plots for the specified columns
columns_to_visualize = ['age']
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[columns_to_visualize])
plt.title("Box Plot of Outliers")
plt.xlabel("Columns")
plt.ylabel("Values")
plt.show()

# %%
# Create box plots for the specified columns
columns_to_visualize = ['cigsPerDay']
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[columns_to_visualize])
plt.title("Box Plot of Outliers")
plt.xlabel("Columns")
plt.ylabel("Values")
plt.show()

# %%
# Calculate IQR
Q1 = df['cigsPerDay'].quantile(0.25)
Q3 = df['cigsPerDay'].quantile(0.75)
IQR = Q3 - Q1
# Define the upper bound for outlier detection (high fence)
upper_bound = Q3 + 1.5 * IQR

# Replace values above the high fence with the high fence value
df['cigsPerDay'] = df['cigsPerDay'].apply(lambda x: upper_bound if x > upper_bound else x)

# %%
# Create box plots for the specified columns
columns_to_visualize = ['totChol']
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[columns_to_visualize])
plt.title("Box Plot of Outliers")
plt.xlabel("Columns")
plt.ylabel("Values")
plt.show()

# %%
# Calculate IQR
Q1 = df['totChol'].quantile(0.25)
Q3 = df['totChol'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection (lower and upper fence)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Replace values below the lower fence with the lower fence value
df['totChol'] = df['totChol'].apply(lambda x: lower_bound if x < lower_bound else x)

# Replace values above the upper fence with the upper fence value
df['totChol'] = df['totChol'].apply(lambda x: upper_bound if x > upper_bound else x)

# %%
# Create box plots for the specified columns
columns_to_visualize = ['sysBP']
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[columns_to_visualize])
plt.title("Box Plot of Outliers")
plt.xlabel("Columns")
plt.ylabel("Values")
plt.show()

# %%
# Calculate IQR
Q1 = df['sysBP'].quantile(0.25)
Q3 = df['sysBP'].quantile(0.75)
IQR = Q3 - Q1
# Define the upper bound for outlier detection (high fence)
upper_bound = Q3 + 1.5 * IQR

# Replace values above the high fence with the high fence value
df['sysBP'] = df['sysBP'].apply(lambda x: upper_bound if x > upper_bound else x)

# %%
# Create box plots for the specified columns
columns_to_visualize = ['BMI']
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[columns_to_visualize])
plt.title("Box Plot of Outliers")
plt.xlabel("Columns")
plt.ylabel("Values")
plt.show()

# %%
# Calculate IQR
Q1 = df['BMI'].quantile(0.25)
Q3 = df['BMI'].quantile(0.75)
IQR = Q3 - Q1
# Define the upper bound for outlier detection (high fence)
upper_bound = Q3 + 1.5 * IQR

# Replace values above the high fence with the high fence value
df['BMI'] = df['BMI'].apply(lambda x: upper_bound if x > upper_bound else x)

# %%
# Create box plots for the specified columns
columns_to_visualize = ['heartRate']
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[columns_to_visualize])
plt.title("Box Plot of Outliers")
plt.xlabel("Columns")
plt.ylabel("Values")
plt.show()

# %%
# Calculate IQR
Q1 = df['heartRate'].quantile(0.25)
Q3 = df['heartRate'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection (lower and upper fence)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Replace values below the lower fence with the lower fence value
df['heartRate'] = df['heartRate'].apply(lambda x: lower_bound if x < lower_bound else x)

# Replace values above the upper fence with the upper fence value
df['heartRate'] = df['heartRate'].apply(lambda x: upper_bound if x > upper_bound else x)

# %%
# Assuming 'df' is your DataFrame containing the columns to visualize
columns_to_visualize = ['age', 'cigsPerDay', 'totChol', 'sysBP', 'BMI', 'heartRate']

# Create box plots for each column
plt.figure(figsize=(12, 8))
for column in columns_to_visualize:
    sns.boxplot(x=column, data=df)
    plt.title(f"Box Plot of {column}")
    plt.show()

# %% [markdown]
# All outliers had been treated and removed upto here

# %%
# Create distribution plots for the specified columns
columns_to_visualize = ['age', 'cigsPerDay', 'totChol', 'sysBP', 'BMI', 'heartRate']

plt.figure(figsize=(12, 8))

for i, column in enumerate(columns_to_visualize, 1):
    plt.subplot(2, 3, i)
    sns.histplot(df[column], kde=True)
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Everything seems to be normally distributed except for "cigsperday." We can apply a log transformation to "cigsperday" to make it normally distributed.

# %%
# Apply log transformation to the 'cigsPerDay' column
df['cigsPerDay'] = np.log1p(df['cigsPerDay'])
print(df)
# Out:
#       age  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  diabetes  \
# 0      64    1.386294       0                0             0         0
# 1      36    0.000000       0                0             1         0
# 2      46    2.397895       0                0             0         0
# 3      50    3.044522       0                0             1         0
# 4      64    3.433987       0                0             0         0
# ...   ...         ...     ...              ...           ...       ...
# 3385   60    0.000000       0                0             0         0
# 3386   46    0.000000       0                0             0         0
# 3387   44    1.386294       0                0             1         0
# 3388   60    0.000000       0                0             1         0
# 3389   54    0.000000       0                0             0         0
#
#       totChol  sysBP    BMI  heartRate  TenYearCHD
# 0       221.0  148.0  25.38       90.0           1
# ...

# %%
# Create distribution plots for the specified columns
columns_to_visualize = ['cigsPerDay']

plt.figure(figsize=(12, 8))

for i, column in enumerate(columns_to_visualize, 1):
    plt.subplot(2, 3, i)
    sns.histplot(df[column], kde=True)
    plt.title(f"Distribution of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# # correletion between dependent and independent features

# %% [markdown]
# # 5) Features Selection

# %%
# Assuming 'dependent_var' is the name of your dependent variable and 'df' is your DataFrame
correlation_matrix = df.corr()
correlation_with_dependent = correlation_matrix['TenYearCHD'].drop('TenYearCHD')
print(correlation_with_dependent)
# Out:
# age                0.224927
# cigsPerDay         0.053560
# BPMeds             0.087349
# prevalentStroke    0.068627
# prevalentHyp       0.166544
# diabetes           0.103681
# totChol            0.091825
# sysBP              0.203803
# BMI                0.064416
# heartRate          0.019719
# Name: TenYearCHD, dtype: float64

# %%
df.drop(['heartRate' , 'cigsPerDay' , 'BPMeds' ,'prevalentStroke' , 'BMI'] ,axis=1 , inplace=True)

# %%
df
# Out:
#       age  prevalentHyp  diabetes  totChol  sysBP  TenYearCHD
# 0      64             0         0    221.0  148.0           1
# 1      36             1         0    212.0  168.0           0
# 2      46             0         0    250.0  116.0           0
# 3      50             1         0    233.0  158.0           1
# 4      64             0         0    241.0  136.0           0
# ...   ...           ...       ...      ...    ...         ...
# 3385   60             0         0    261.0  123.0           0
# 3386   46             0         0    199.0  102.0           0
# 3387   44             1         0    351.0  164.0           1
# 3388   60             1         0    191.0  167.0           0
# 3389   54             0         0    288.0  124.0           0
#
# [3390 rows x 6 columns]

# %% [markdown]
# # 6) Features scaling

# %%
# Assuming 'target' is the name of the target attribute
x = df.drop('TenYearCHD', axis=1)
y = df['TenYearCHD']

# %%
x.shape
# Out:
# (3390, 5)

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 3385    0
# 3386    0
# 3387    1
# 3388    0
# 3389    0
# Name: TenYearCHD, Length: 3390, dtype: int64

# %%
from sklearn.datasets import make_classification
x, y = make_classification(n_samples=3000, n_classes=2, weights=[1,1], random_state=42 , n_features=5)

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform it
X_train_scaled = scaler.fit_transform(X_train)

# Transform the test data using the fitted scaler
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # model-1(LOGISTIC REGRESSION)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
# Create and train the logistic regression model
model_2 = LogisticRegression()
model_2.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = model_2.predict(X_test_scaled)

# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)


print("Accuracy:", accuracy)
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(classification_rep)
print("Recall:", recall)
print("Precision:", precision)
# Out:
# Accuracy: 0.9633333333333334
# Confusion Matrix:
# [[296  20]
#  [  2 282]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.96       316
#            1       0.93      0.99      0.96       284
#
#     accuracy                           0.96       600
#    macro avg       0.96      0.96      0.96       600
# weighted avg       0.97      0.96      0.96       600
#
# Recall: 0.9929577464788732
# Precision: 0.9337748344370861

# %% [markdown]
# # Model-2(GradientBoostingClassifier)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Create the GradientBoostingClassifier
clf = GradientBoostingClassifier()

# %%
# Train the classifier
clf.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Calculate accuracy, precision, and recall
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
# Out:
# Accuracy: 0.98
# Precision: 0.98
# Recall: 0.98

# %% [markdown]
# # Model-3(RandomForestClassifier)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Create the RandomForestClassifier
clf2 = RandomForestClassifier()

# Train the classifier
clf2.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = clf2.predict(X_test_scaled)

# Calculate accuracy, precision, and recall
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
# Out:
# Accuracy: 0.98
# Precision: 0.98
# Recall: 0.98
